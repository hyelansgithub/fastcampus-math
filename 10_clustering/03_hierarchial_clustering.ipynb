# %% [markdown]
# ## 01장. 클러스터링
# ### 3. 계층적 클러스터링

# %%
from scipy.cluster.hierarchy import linkage, dendrogram
import numpy as np
import matplotlib.pylab as plt
import matplotlib as mpl

# %%
np.set_printoptions(precision=5, suppress=True) 

np.random.seed(4711)  # for repeatability of this tutorial
a = np.random.multivariate_normal([10, 0], [[3, 1], [1, 4]], size=[100,])
b = np.random.multivariate_normal([0, 20], [[3, 1], [1, 4]], size=[50,])
X = np.concatenate((a, b),)
print(X.shape)

plt.scatter(X[:,0], X[:,1], s=50)
plt.show()
# Out:
# (150, 2)

# %%
X
# Out:
# array([[ 9.21188, -0.15189],
#        [ 8.88937, -0.33937],
#        [10.7684 ,  2.95245],
#        [ 8.24213,  1.29095],
#        [ 5.7967 , -5.83777],
#        [ 6.34993,  0.6396 ],
#        [ 8.10571, -0.45887],
#        [ 8.72085, -4.40444],
#        [ 8.83501, -0.39166],
#        [10.40061,  2.71241],
#        [11.95503,  1.98603],
#        [ 8.50142,  0.5035 ],
#        [ 9.23359,  1.30693],
#        [12.27768,  1.62764],
#        [10.95902, -0.12752],
#        [ 8.72437, -0.73102],
#        [ 9.64949,  3.41989],
#        [11.49912, -0.55113],
#        [11.48256, -0.28623],
#        [ 8.5874 ,  1.66814],
#        [11.9557 , -1.27351],
#        [ 9.85622,  1.08989],
#        [10.11831,  1.08458],
#        [ 7.76042,  0.63747],
#        [10.99794, -2.93747],
#        [ 6.9085 , -1.44868],
#        [ 7.85787, -0.99148],
#        [ 6.12508, -2.44306],
#        [10.61144, -0.23623],
#        [11.09217, -1.69984],
#        [ 7.15907, -0.12267],
#        [10.73784, -1.63561],
# ...

# %% [markdown]
# ### linkage
#     - linkage(데이터, '데이터 거리 측정 방식')
#     - 계층적 클러스터링 해준다.

# %%
Z = linkage(X, 'ward')

# %% [markdown]
#     - 클러스터링 이후 4개의 특성을 output으로 반환하는데
#     - 클러스터 넘버 2개, 두개의 클러스터 간 거리, 클러스터의 cardinality 원소개수

# %%
Z[:20]
# Out:
# array([[ 52.     ,  53.     ,   0.04151,   2.     ],
#        [ 14.     ,  79.     ,   0.05914,   2.     ],
#        [ 33.     ,  68.     ,   0.07107,   2.     ],
#        [ 17.     ,  73.     ,   0.07137,   2.     ],
#        [  1.     ,   8.     ,   0.07543,   2.     ],
#        [ 85.     ,  95.     ,   0.10928,   2.     ],
#        [108.     , 131.     ,   0.11007,   2.     ],
#        [  9.     ,  66.     ,   0.11302,   2.     ],
#        [ 15.     ,  69.     ,   0.11429,   2.     ],
#        [ 63.     ,  98.     ,   0.1212 ,   2.     ],
#        [107.     , 115.     ,   0.12167,   2.     ],
#        [ 65.     ,  74.     ,   0.1249 ,   2.     ],
#        [ 58.     ,  61.     ,   0.14028,   2.     ],
#        [ 62.     , 152.     ,   0.1726 ,   3.     ],
#        [ 41.     , 158.     ,   0.1779 ,   3.     ],
#        [ 10.     ,  83.     ,   0.18635,   2.     ],
#        [114.     , 139.     ,   0.20419,   2.     ],
#        [ 39.     ,  88.     ,   0.20628,   2.     ],
# ...

# %%
idxs = [33, 68, 62, 82, 63, 98]
plt.figure(figsize=(10, 10))
plt.scatter(X[:,0], X[:,1], s=50)
plt.scatter(X[idxs,0], X[idxs,1], c='r', s=100) 
plt.show()

# %% [markdown]
#     아래의 데이터만 빨갛게 표시

# %%
X[idxs,0]
# Out:
# array([ 9.83913,  9.89349,  9.97793, 10.06665,  9.6348 ,  9.62903])

# %%
X[idxs,1]
# Out:
# array([-0.4873 , -0.44152, -0.56383, -0.79825, -0.90549, -0.78443])

# %% [markdown]
# ### dendrogram
#     - 계층적 클러스터링 시각화 해준다.

# %%
mpl.rcParams["font.family"] = 'DejaVu Sans'
plt.figure(figsize=(10,30))
ax = plt.subplot(111)
dendrogram(Z, leaf_font_size=10, orientation='right')
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('sample index')
plt.ylabel('distance')
ax.set_xlim(xmin=0.03)
ax.set_xscale('log')
plt.show()

# %% [markdown]
#     - 왼쪽에 클러스터 넘버는 연관성 있는 것 끼리 재배열되어 있는 상태
#     - 왼쪽부터 클러스터가 합쳐지는 순서를 알 수 있음
